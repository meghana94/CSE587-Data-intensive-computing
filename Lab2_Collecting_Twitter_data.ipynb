# %% [markdown]
# # Meghana And Divya

# %% [markdown]
# # Collecting twitter data

# %%
import tweepy
import csv
import pandas as pd

consumer_key = '5X1UGbcSIOL4UVZBCwz0QDExz'
consumer_secret = 'zIJFYt7vPjdxUXUaZ1bOjITD113uEQOzQ88W87zh2ZH49tayG0'
access_token = '2648432046-f1SpAPzFj4cghNyoHObiy3X42kuSMyekpIWmFoz'
access_secret = 'uiHCHoQqb9EpPjSnPxnsEdEyRS4UgKZAGFRTArtxssWsH'

auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_secret)
api = tweepy.API(auth,wait_on_rate_limit=True)

csvFile = open('sports.txt', 'a')
csvWriter = csv.writer(csvFile)
for tweet in tweepy.Cursor(api.search,q="sports",
                           tweet_mode='extended',lang="en",
                           since="2019-01-01").items(500000):
    if (not tweet.retweeted) and ('RT @' not in tweet.full_text):

        print (tweet.full_text)
        csvWriter.writerow([tweet.full_text.encode('utf-8')])

csvFile.close()

# %%
import tweepy
import csv
import pandas as pd

consumer_key = '5X1UGbcSIOL4UVZBCwz0QDExz'
consumer_secret = 'zIJFYt7vPjdxUXUaZ1bOjITD113uEQOzQ88W87zh2ZH49tayG0'
access_token = '2648432046-f1SpAPzFj4cghNyoHObiy3X42kuSMyekpIWmFoz'
access_secret = 'uiHCHoQqb9EpPjSnPxnsEdEyRS4UgKZAGFRTArtxssWsH'

auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_secret)
api = tweepy.API(auth,wait_on_rate_limit=True)

csvFile = open('cricket.txt', 'a')
csvWriter = csv.writer(csvFile)
for tweet in tweepy.Cursor(api.search,q="cricket",
                           tweet_mode='extended',lang="en",
                           since="2019-01-01").items(500000):
    if (not tweet.retweeted) and ('RT @' not in tweet.full_text):

        print (tweet.full_text)
        csvWriter.writerow([tweet.full_text.encode('utf-8')])

csvFile.close()

# %%
import tweepy
import csv
import pandas as pd

consumer_key = '5X1UGbcSIOL4UVZBCwz0QDExz'
consumer_secret = 'zIJFYt7vPjdxUXUaZ1bOjITD113uEQOzQ88W87zh2ZH49tayG0'
access_token = '2648432046-f1SpAPzFj4cghNyoHObiy3X42kuSMyekpIWmFoz'
access_secret = 'uiHCHoQqb9EpPjSnPxnsEdEyRS4UgKZAGFRTArtxssWsH'

auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_secret)
api = tweepy.API(auth,wait_on_rate_limit=True)

csvFile = open('football.txt', 'a')
csvWriter = csv.writer(csvFile)
for tweet in tweepy.Cursor(api.search,q="football",
                           tweet_mode='extended',lang="en",
                           since="2019-01-01").items(500000):
    if (not tweet.retweeted) and ('RT @' not in tweet.full_text):

        print (tweet.full_text)
        csvWriter.writerow([tweet.full_text.encode('utf-8')])

csvFile.close()

# %%
import tweepy
import csv
import pandas as pd

consumer_key = '5X1UGbcSIOL4UVZBCwz0QDExz'
consumer_secret = 'zIJFYt7vPjdxUXUaZ1bOjITD113uEQOzQ88W87zh2ZH49tayG0'
access_token = '2648432046-f1SpAPzFj4cghNyoHObiy3X42kuSMyekpIWmFoz'
access_secret = 'uiHCHoQqb9EpPjSnPxnsEdEyRS4UgKZAGFRTArtxssWsH'

auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_secret)
api = tweepy.API(auth,wait_on_rate_limit=True)

csvFile = open('golf.txt', 'a')
csvWriter = csv.writer(csvFile)
for tweet in tweepy.Cursor(api.search,q="golf",
                           tweet_mode='extended',lang="en",
                           since="2019-01-01").items(500000):
    if (not tweet.retweeted) and ('RT @' not in tweet.full_text):

        print (tweet.full_text)
        csvWriter.writerow([tweet.full_text.encode('utf-8')])

csvFile.close()

# %%
import tweepy
import csv
import pandas as pd

consumer_key = '5X1UGbcSIOL4UVZBCwz0QDExz'
consumer_secret = 'zIJFYt7vPjdxUXUaZ1bOjITD113uEQOzQ88W87zh2ZH49tayG0'
access_token = '2648432046-f1SpAPzFj4cghNyoHObiy3X42kuSMyekpIWmFoz'
access_secret = 'uiHCHoQqb9EpPjSnPxnsEdEyRS4UgKZAGFRTArtxssWsH'

auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_secret)
api = tweepy.API(auth,wait_on_rate_limit=True)

csvFile = open('tennis.txt', 'a')
csvWriter = csv.writer(csvFile)
for tweet in tweepy.Cursor(api.search,q="tennis",
                           tweet_mode='extended',lang="en",
                           since="2019-01-01").items(500000):
    if (not tweet.retweeted) and ('RT @' not in tweet.full_text):

        print (tweet.full_text)
        csvWriter.writerow([tweet.full_text.encode('utf-8')])

csvFile.close()

# %%
import tweepy
import csv
import pandas as pd

consumer_key = '5X1UGbcSIOL4UVZBCwz0QDExz'
consumer_secret = 'zIJFYt7vPjdxUXUaZ1bOjITD113uEQOzQ88W87zh2ZH49tayG0'
access_token = '2648432046-f1SpAPzFj4cghNyoHObiy3X42kuSMyekpIWmFoz'
access_secret = 'uiHCHoQqb9EpPjSnPxnsEdEyRS4UgKZAGFRTArtxssWsH'

auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_secret)
api = tweepy.API(auth,wait_on_rate_limit=True)

csvFile = open('swimming.txt', 'a')
csvWriter = csv.writer(csvFile)
for tweet in tweepy.Cursor(api.search,q="swimming",
                           tweet_mode='extended',lang="en",
                           since="2019-01-01").items(500000):
    if (not tweet.retweeted) and ('RT @' not in tweet.full_text):

        print (tweet.full_text)
        csvWriter.writerow([tweet.full_text.encode('utf-8')])

csvFile.close()

# %%
import tweepy
import csv
import pandas as pd

consumer_key = '5X1UGbcSIOL4UVZBCwz0QDExz'
consumer_secret = 'zIJFYt7vPjdxUXUaZ1bOjITD113uEQOzQ88W87zh2ZH49tayG0'
access_token = '2648432046-f1SpAPzFj4cghNyoHObiy3X42kuSMyekpIWmFoz'
access_secret = 'uiHCHoQqb9EpPjSnPxnsEdEyRS4UgKZAGFRTArtxssWsH'

auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_secret)
api = tweepy.API(auth,wait_on_rate_limit=True)

csvFile = open('basketball.txt', 'a')
csvWriter = csv.writer(csvFile)
for tweet in tweepy.Cursor(api.search,q="basketball",
                           tweet_mode='extended',lang="en",
                           since="2019-01-01").items(500000):
    if (not tweet.retweeted) and ('RT @' not in tweet.full_text):

        print (tweet.full_text)
        csvWriter.writerow([tweet.full_text.encode('utf-8')])

csvFile.close()
# Out:
# @stephenasmith Basketball isn't only about offense. The guy doesn't/can't play defense
# Yesterday 16.04.2019 our iTipster Tips Result
#
# iTipster Tips UEFA Champion League :
#
# Juventus vs Ajax Amsterdam
#
# Tips : Over 2.5/3
#
# Result : 1-2
#
# Win
#
# The Most Trusted #1 Soccer and Basketball Tipster Service Web Site
#
# Tipster Tips Group
# https://t.co/BQAKSzAUO4 https://t.co/zLGaqsoDAH
# @eddy_3333 @cwhit50 @PrepHoopsWA @Sehomehs @SPU_Basketball Turn me up!💪🏾
# @Birchola Checkmate 😁, reached higer rates years ago (2011) even before go to any tennis matches when I was trading football and basketball.
# @YoloJonathan_ And that’s our last convo abt basketball
# This is coming from a florida fan who's first basketball experience was Florida win b2b titles. Billy D is a legend but for two years with the same ELITE roster nothing to show https://t.co/5KZzMkOde0
# @IndieGamerChick The Blazers gag nearly every time they're in the playoffs, so I'll take this win.
#
# ...

# %%
import tweepy
import csv
import pandas as pd

consumer_key = '5X1UGbcSIOL4UVZBCwz0QDExz'
consumer_secret = 'zIJFYt7vPjdxUXUaZ1bOjITD113uEQOzQ88W87zh2ZH49tayG0'
access_token = '2648432046-f1SpAPzFj4cghNyoHObiy3X42kuSMyekpIWmFoz'
access_secret = 'uiHCHoQqb9EpPjSnPxnsEdEyRS4UgKZAGFRTArtxssWsH'

auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_secret)
api = tweepy.API(auth,wait_on_rate_limit=True)

csvFile = open('baseball.txt', 'a')
csvWriter = csv.writer(csvFile)
for tweet in tweepy.Cursor(api.search,q="baseball",
                           tweet_mode='extended',lang="en",
                           since="2019-01-01").items(500000):
    if (not tweet.retweeted) and ('RT @' not in tweet.full_text):

        print (tweet.full_text)
        csvWriter.writerow([tweet.full_text.encode('utf-8')])

csvFile.close()

# %%
filenames = ['finalsports.txt','baseball.txt','basketball.txt']
with open('Twitterfinalsports.txt', 'w') as outfile:
    for fname in filenames:
        with open(fname) as infile:
            for line in infile:
                outfile.write(line)
